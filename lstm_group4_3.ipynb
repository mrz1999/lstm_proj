# %% [markdown]
# ## GROUP MEMBER
# - Lorenza Di Mauro
# - Raffaele Sannino
# - Maria Zampella

# %% [markdown]
# ## **DATASET AND MAIN GOAL**
# In this notebook we have to deal with a multidimensional time series dataset concerning the concentrations of some pollutants in a significant polluted area, in an Italian city. The dataset is available on https://archive.ics.uci.edu/ml/datasets/air+quality. Quoting the description of the dataset: *The dataset contains 9358 instances of hourly averaged responses from an array of 5 metal oxide chemical sensors embedded in an Air Quality Chemical Multisensor Device. The device was located on the field in a significantly polluted area, at road level,within an Italian city. Data were recorded from March 2004 to February 2005 (one year)representing the longest freely available recordings of on field deployed air quality chemical sensor devices responses.*
#
# Our goal basically is to make predictions aboout the concentration of CO by using LSTM and Bidirectional-LSTM.
#
# Let's start by taking a look at the dataset.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = r'AirQualityUCI.xlsx'
dataset = pd.read_excel(dataset_path)
dataset
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# 1            954.75    103.0       1173.75     92.0       1558.75
# 2            939.25    131.0       1140.00    114.0       1554.50
# 3            948.25    172.0       1092.00    122.0       1583.75
# 4            835.50    131.0       1205.00    116.0       1490.00
# ...             ...      ...           ...      ...           ...
# 9352        1101.25    471.7        538.50    189.8       1374.25
# 9353        1027.00    353.3        603.75    179.2       1263.50
# 9354        1062.50    293.0        603.25    174.7       1240.75
# 9355         960.50    234.5        701.50    155.7       1041.00
# 9356        1047.25    265.2        654.00    167.7       1128.50
#
#       PT08.S5(O3)       T         RH        AH
# 0         1267.50  13.600  48.875001  0.757754
# 1          972.25  13.300  47.700000  0.725487
# 2         1074.00  11.900  53.975000  0.750239
# 3         1203.25  11.000  60.000000  0.786713
# 4         1110.00  11.150  59.575001  0.788794
# ...           ...     ...        ...       ...
# 9352      1728.50  21.850  29.250000  0.756824
# 9353      1269.00  24.325  23.725000  0.711864
# 9354      1092.00  26.900  18.350000  0.640649
# 9355       769.75  28.325  13.550000  0.513866
# 9356       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 15 columns]

# %%
# dataset_path = r'/content/drive/MyDrive/AirQualityUCI/AirQualityUCI.xlsx'
# dataset = pd.read_excel(dataset_path)
# dataset

# %%
dataset.describe(include = 'all')
# Out:
# <ipython-input-5-a7fe9e1cc73d>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataset.describe(include = 'all')
#                        Date      Time       CO(GT)  PT08.S1(CO)     NMHC(GT)  \
# count                  9357      9357  9357.000000  9357.000000  9357.000000
# unique                  391        24          NaN          NaN          NaN
# top     2004-09-21 00:00:00  18:00:00          NaN          NaN          NaN
# freq                     24       390          NaN          NaN          NaN
# first   2004-03-10 00:00:00       NaN          NaN          NaN          NaN
# last    2005-04-04 00:00:00       NaN          NaN          NaN          NaN
# mean                    NaN       NaN   -34.207524  1048.869652  -159.090093
# std                     NaN       NaN    77.657170   329.817015   139.789093
# min                     NaN       NaN  -200.000000  -200.000000  -200.000000
# 25%                     NaN       NaN     0.600000   921.000000  -200.000000
# 50%                     NaN       NaN     1.500000  1052.500000  -200.000000
# 75%                     NaN       NaN     2.600000  1221.250000  -200.000000
# max                     NaN       NaN    11.900000  2039.750000  1189.000000
#
#            C6H6(GT)  PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)      NO2(GT)  \
# count   9357.000000    9357.000000  9357.000000   9357.000000  9357.000000
# unique          NaN            NaN          NaN           NaN          NaN
# top             NaN            NaN          NaN           NaN          NaN
# freq            NaN            NaN          NaN           NaN          NaN
# first           NaN            NaN          NaN           NaN          NaN
# last            NaN            NaN          NaN           NaN          NaN
# mean       1.865576     894.475963   168.604200    794.872333    58.135898
# std       41.380154     342.315902   257.424561    321.977031   126.931428
# min     -200.000000    -200.000000  -200.000000   -200.000000  -200.000000
# 25%        4.004958     711.000000    50.000000    637.000000    53.000000
# 50%        7.886653     894.500000   141.000000    794.250000    96.000000
# 75%       13.636091    1104.750000   284.200000    960.250000   133.000000
# max       63.741476    2214.000000  1479.000000   2682.750000   339.700000
#
#         PT08.S4(NO2)  PT08.S5(O3)            T           RH           AH
# count    9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# unique           NaN          NaN          NaN          NaN          NaN
# top              NaN          NaN          NaN          NaN          NaN
# freq             NaN          NaN          NaN          NaN          NaN
# first            NaN          NaN          NaN          NaN          NaN
# last             NaN          NaN          NaN          NaN          NaN
# mean     1391.363266   974.951534     9.776600    39.483611    -6.837604
# std       467.192382   456.922728    43.203438    51.215645    38.976670
# min      -200.000000  -200.000000  -200.000000  -200.000000  -200.000000
# 25%      1184.750000   699.750000    10.950000    34.050000     0.692275
# 50%      1445.500000   942.000000    17.200000    48.550000     0.976823
# 75%      1662.000000  1255.250000    24.075000    61.875000     1.296223
# max      2775.000000  2522.750000    44.600000    88.725000     2.231036

# %%
feat = list(dataset.columns)
feat = feat[2:]
a = len(feat)
# We decide to use 4 columns and 4 rows
c = 1
fig = plt.figure(figsize=(30,20))
for i in feat:
    plt.subplot(5, 3, c)
    plt.title(str(i) + ' VS Time', fontsize = 'xx-large')
    #plt.ylabel(i)
    # plt.xlabel('Date')
    plt.plot(dataset[i])
    c = c + 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(dataset.index, dataset['CO(GT)'], label='x', 
         linewidth=1)

# Add title and labels
plt.title('CO concentrations')
plt.xlabel('Timesteps')
plt.ylabel('CO (GT)')

# Add legend
plt.legend()

# Auto space
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# ## **Data cleaning and data visualization**
# So, considered what we have just seen, there aro some serious irregularities in the time series. Actually, in the description of the dataset given by the author ***(Saverio De Vito (saverio.devito '@' enea.it), ENEA - National Agency for New Technologies, Energy and Sustainable Economic Development)*** it is written that all the *Nan* values are setted to the value ***-200***

# %%
dataset = dataset.where(dataset != -200)
dataset
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00     150.0  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25     112.0   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00      88.0   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50      80.0   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25      51.0   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25       NaN  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50       NaN  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00       NaN  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50       NaN   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75       NaN  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# 1            954.75    103.0       1173.75     92.0       1558.75
# 2            939.25    131.0       1140.00    114.0       1554.50
# 3            948.25    172.0       1092.00    122.0       1583.75
# 4            835.50    131.0       1205.00    116.0       1490.00
# ...             ...      ...           ...      ...           ...
# 9352        1101.25    471.7        538.50    189.8       1374.25
# 9353        1027.00    353.3        603.75    179.2       1263.50
# 9354        1062.50    293.0        603.25    174.7       1240.75
# 9355         960.50    234.5        701.50    155.7       1041.00
# 9356        1047.25    265.2        654.00    167.7       1128.50
#
#       PT08.S5(O3)       T         RH        AH
# 0         1267.50  13.600  48.875001  0.757754
# 1          972.25  13.300  47.700000  0.725487
# 2         1074.00  11.900  53.975000  0.750239
# 3         1203.25  11.000  60.000000  0.786713
# 4         1110.00  11.150  59.575001  0.788794
# ...           ...     ...        ...       ...
# 9352      1728.50  21.850  29.250000  0.756824
# 9353      1269.00  24.325  23.725000  0.711864
# 9354      1092.00  26.900  18.350000  0.640649
# 9355       769.75  28.325  13.550000  0.513866
# 9356       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 15 columns]

# %%
# We print the type of the columns because we want to analyze if there are some categorical variables.

for column in dataset.columns:
    print(column, ':' , dataset[column].dtype)

# In this case all the columns are numerical one (except the first two that represents the time stamp).
# Out:
# Date : datetime64[ns]
# Time : object
# CO(GT) : float64
# PT08.S1(CO) : float64
# NMHC(GT) : float64
# C6H6(GT) : float64
# PT08.S2(NMHC) : float64
# NOx(GT) : float64
# PT08.S3(NOx) : float64
# NO2(GT) : float64
# PT08.S4(NO2) : float64
# PT08.S5(O3) : float64
# T : float64
# RH : float64
# AH : float64

# %%
#OBSERVE THE NUMBER FOR MISSING DATA FOR EACH COLUMN
print(dataset.isnull().sum())

print('Total number of rows = ', len(dataset) )
# Out:
# Date                0
# Time                0
# CO(GT)           1683
# PT08.S1(CO)       366
# NMHC(GT)         8443
# C6H6(GT)          366
# PT08.S2(NMHC)     366
# NOx(GT)          1639
# PT08.S3(NOx)      366
# NO2(GT)          1642
# PT08.S4(NO2)      366
# PT08.S5(O3)       366
# T                 366
# RH                366
# AH                366
# dtype: int64
# Total number of rows =  9357

# %% [markdown]
# We notice that the column NMHC contains a considerable number of **Null values** (more precisely: 8443/9357 = about **90%**), so for our analysis we decide to remove this column.

# %%
del dataset['NMHC(GT)']

# %% [markdown]
# By looking at the number of Null values for columns we noticed that more columns have the same number, so we thought that maybe **there are some rows (that is: some specific hours for some specific days) in which data were not properly collected**. Let's check if there are some rows with more than one null value

# %%
# for example we select the 'AH' column. And we selct only the rows which has NaN for that column.

dataset[dataset['AH'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, Time, CO(GT), PT08.S1(CO), C6H6(GT), PT08.S2(NMHC), NOx(GT), PT08.S3(NOx), NO2(GT), PT08.S4(NO2), PT08.S5(O3), T, RH, AH]
# Index: []

# %%
# Now we visualize the number on NaN for each column for this restricted dataset

print(dataset[dataset['AH']. isnull()].isnull().sum())

# so we can say that the 366 rows with NaN are the same for :
# PT08.S1(CO), C6H6(GT), PT08.S2(NMHC), PT08.S3(NOx), PT08.S4(NO2),PT08.S5(O3), T, RH, AH (IT LOOKS THAT THESE ALMOST-NULL ROWS ARE CONSECUTIVES)
# Out:
# Date               0
# Time               0
# CO(GT)            36
# PT08.S1(CO)      366
# C6H6(GT)         366
# PT08.S2(NMHC)    366
# NOx(GT)           44
# PT08.S3(NOx)     366
# NO2(GT)           44
# PT08.S4(NO2)     366
# PT08.S5(O3)      366
# T                366
# RH               366
# AH               366
# dtype: int64

# %% [markdown]
# So we can say that the 366 rows with NaN are the same for : PT08.S1(CO), C6H6(GT), PT08.S2(NMHC), PT08.S3(NOx), PT08.S4(NO2), PT08.S5(O3), T, RH, AH.
#
# **NOTE: It looks that these almost-null rows are consecutives. In this case, we have to delete them because it means that our forecasting will be seriously invalidated (almost in a specific time range)**

# %% [markdown]
# We decided not to discarge the rows containing NaN values, instead **we substitute them with means.**

# %%
dataset = dataset.fillna(dataset.mean())
dataset
# Out:
# <ipython-input-13-eb8e3ba4ef6d>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   dataset = dataset.fillna(dataset.mean())
# <ipython-input-13-eb8e3ba4ef6d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset = dataset.fillna(dataset.mean())
#            Date      Time  CO(GT)  PT08.S1(CO)   C6H6(GT)  PT08.S2(NMHC)  \
# 0    2004-03-10  18:00:00     2.6      1360.00  11.881723        1045.50
# 1    2004-03-10  19:00:00     2.0      1292.25   9.397165         954.75
# 2    2004-03-10  20:00:00     2.2      1402.00   8.997817         939.25
# 3    2004-03-10  21:00:00     2.2      1375.50   9.228796         948.25
# 4    2004-03-10  22:00:00     1.6      1272.25   6.518224         835.50
# ...         ...       ...     ...          ...        ...            ...
# 9352 2005-04-04  10:00:00     3.1      1314.25  13.529605        1101.25
# 9353 2005-04-04  11:00:00     2.4      1162.50  11.355157        1027.00
# 9354 2005-04-04  12:00:00     2.4      1142.00  12.374538        1062.50
# 9355 2005-04-04  13:00:00     2.1      1002.50   9.547187         960.50
# 9356 2005-04-04  14:00:00     2.2      1070.75  11.932060        1047.25
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T  \
# 0       166.0       1056.25    113.0       1692.00      1267.50  13.600
# 1       103.0       1173.75     92.0       1558.75       972.25  13.300
# 2       131.0       1140.00    114.0       1554.50      1074.00  11.900
# 3       172.0       1092.00    122.0       1583.75      1203.25  11.000
# 4       131.0       1205.00    116.0       1490.00      1110.00  11.150
# ...       ...           ...      ...           ...          ...     ...
# 9352    471.7        538.50    189.8       1374.25      1728.50  21.850
# 9353    353.3        603.75    179.2       1263.50      1269.00  24.325
# 9354    293.0        603.25    174.7       1240.75      1092.00  26.900
# 9355    234.5        701.50    155.7       1041.00       769.75  28.325
# 9356    265.2        654.00    167.7       1128.50       816.00  28.500
#
#              RH        AH
# 0     48.875001  0.757754
# 1     47.700000  0.725487
# 2     53.975000  0.750239
# 3     60.000000  0.786713
# 4     59.575001  0.788794
# ...         ...       ...
# 9352  29.250000  0.756824
# 9353  23.725000  0.711864
# 9354  18.350000  0.640649
# 9355  13.550000  0.513866
# 9356  13.125000  0.502804
#
# [9357 rows x 14 columns]

# %%
# Let's check if we replaced all the NaN values
nan_in_df = dataset.isnull().values.any()
nan_in_df
# Out:
# False

# %%
dataset.describe(include = 'all').T
# Out:
# <ipython-input-15-e97782cb9a28>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   dataset.describe(include = 'all').T
#                 count unique                  top freq      first       last  \
# Date             9357    391  2004-09-21 00:00:00   24 2004-03-10 2005-04-04
# Time             9357     24             18:00:00  390        NaT        NaT
# CO(GT)         9357.0    NaN                  NaN  NaN        NaT        NaT
# PT08.S1(CO)    9357.0    NaN                  NaN  NaN        NaT        NaT
# C6H6(GT)       9357.0    NaN                  NaN  NaN        NaT        NaT
# PT08.S2(NMHC)  9357.0    NaN                  NaN  NaN        NaT        NaT
# NOx(GT)        9357.0    NaN                  NaN  NaN        NaT        NaT
# PT08.S3(NOx)   9357.0    NaN                  NaN  NaN        NaT        NaT
# NO2(GT)        9357.0    NaN                  NaN  NaN        NaT        NaT
# PT08.S4(NO2)   9357.0    NaN                  NaN  NaN        NaT        NaT
# PT08.S5(O3)    9357.0    NaN                  NaN  NaN        NaT        NaT
# T              9357.0    NaN                  NaN  NaN        NaT        NaT
# RH             9357.0    NaN                  NaN  NaN        NaT        NaT
# AH             9357.0    NaN                  NaN  NaN        NaT        NaT
#
#                       mean         std       min       25%          50%  \
# Date                   NaN         NaN       NaN       NaN          NaN
# Time                   NaN         NaN       NaN       NaN          NaN
# CO(GT)             2.15275    1.316068       0.1       1.2      2.15275
# PT08.S1(CO)    1099.707856  212.796116    647.25    941.25       1074.5
# C6H6(GT)         10.082993    7.302474  0.149048  4.591495     8.593367
# PT08.S2(NMHC)   939.029205  261.557856    383.25     742.5       923.25
# NOx(GT)         246.881252  193.419417       2.0     112.0        229.0
# PT08.S3(NOx)    835.370973  251.741784     322.0     665.5        817.5
# NO2(GT)         113.075515   43.911095       2.0      85.9   113.075515
# PT08.S4(NO2)   1456.143486  339.365351     551.0    1241.5  1456.143486
# PT08.S5(O3)    1022.780725     390.609     221.0    741.75        982.5
# T                18.316054    8.658396      -1.9    12.025       18.275
# RH                49.23236   16.974308     9.175     36.55     49.23236
# AH                 1.02553    0.395836  0.184679  0.746115     1.015441
#
#                      75%        max
# Date                 NaN        NaN
# Time                 NaN        NaN
# CO(GT)               2.6       11.9
# PT08.S1(CO)      1221.25    2039.75
# C6H6(GT)       13.636091  63.741476
# PT08.S2(NMHC)    1104.75     2214.0
# NOx(GT)            284.2     1479.0
# PT08.S3(NOx)      960.25    2682.75
# NO2(GT)            133.0      339.7
# PT08.S4(NO2)      1662.0     2775.0
# PT08.S5(O3)      1255.25    2522.75
# T                 24.075       44.6
# RH                61.875     88.725
# AH              1.296223   2.231036

# %% [markdown]
# We plot again all the columns of the dataset after removing the NaN values for observing the time series which we use for our analysis.

# %%
feat = list(dataset.columns)
feat = feat[2:]
a = len(feat)
# We decide to use 4 columns and 4 rows
c = 1
fig = plt.figure(figsize=(30,20))
for i in feat:
    plt.subplot(5, 3, c)
    plt.title(str(i) + ' VS Time', fontsize = 'xx-large')
    #plt.ylabel(i)
    # plt.xlabel('Date')
    plt.plot(dataset[i])
    c = c + 1

plt.tight_layout()
plt.show()

# %% [markdown]
# Now we can plot the CO concentrations and show that the negative values (-200) are no longer there.

# %%
plt.figure(figsize=(12,5))
plt.plot(dataset.index, dataset['CO(GT)'], label='x', 
         linewidth=1)

# Add title and labels
plt.title('CO concentrations')
plt.xlabel('Timesteps')
plt.ylabel('CO (GT)')
plt.ylim(0,13)


# Add legend
plt.legend()

# Auto space
plt.tight_layout()

# Display plot
plt.show()

# %% [markdown]
# We want to see the behaviour of CO per day for observing if there are repeated pattern.

# %%
# So we need first to group the data (we calculate the mean of CO per day and then we plot it)

df = dataset.groupby('Date').mean()

plt.figure(figsize=(12,5))
plt.plot(df.index, df['CO(GT)'], label='x', 
         linewidth=1)

# Add title and labels
plt.title('CO concentrations per day')
plt.xlabel('Timesteps')
plt.ylabel('CO (GT)')
plt.ylim(-5,8)


# Add legend
plt.legend()

# Auto space
plt.tight_layout()

# Display plot
plt.show()

# %%
dataset.boxplot(figsize= (18,10))

# %% [markdown]
# ## CORRELATION MATRIX

# %%
# calculate the correlation matrix
corr = dataset.corr()

# plot the correlation matrix (but only half matrix)
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   if sys.path[0] == '':
# <style type="text/css">
# #T_66479_row0_col0, #T_66479_row0_col1, #T_66479_row0_col2, #T_66479_row0_col3, #T_66479_row0_col4, #T_66479_row0_col5, #T_66479_row0_col6, #T_66479_row0_col7, #T_66479_row0_col8, #T_66479_row0_col9, #T_66479_row0_col10, #T_66479_row0_col11, #T_66479_row1_col1, #T_66479_row1_col2, #T_66479_row1_col3, #T_66479_row1_col4, #T_66479_row1_col5, #T_66479_row1_col6, #T_66479_row1_col7, #T_66479_row1_col8, #T_66479_row1_col9, #T_66479_row1_col10, #T_66479_row1_col11, #T_66479_row2_col2, #T_66479_row2_col3, #T_66479_row2_col4, #T_66479_row2_col5, #T_66479_row2_col6, #T_66479_row2_col7, #T_66479_row2_col8, #T_66479_row2_col9, #T_66479_row2_col10, #T_66479_row2_col11, #T_66479_row3_col3, #T_66479_row3_col4, #T_66479_row3_col5, #T_66479_row3_col6, #T_66479_row3_col7, #T_66479_row3_col8, #T_66479_row3_col9, #T_66479_row3_col10, #T_66479_row3_col11, #T_66479_row4_col4, #T_66479_row4_col5, #T_66479_row4_col6, #T_66479_row4_col7, #T_66479_row4_col8, #T_66479_row4_col9, #T_66479_row4_col10, #T_66479_row4_col11, #T_66479_row5_col5, #T_66479_row5_col6, #T_66479_row5_col7, #T_66479_row5_col8, #T_66479_row5_col9, #T_66479_row5_col10, #T_66479_row5_col11, #T_66479_row6_col6, #T_66479_row6_col7, #T_66479_row6_col8, #T_66479_row6_col9, #T_66479_row6_col10, #T_66479_row6_col11, #T_66479_row7_col7, #T_66479_row7_col8, #T_66479_row7_col9, #T_66479_row7_col10, #T_66479_row7_col11, #T_66479_row8_col8, #T_66479_row8_col9, #T_66479_row8_col10, #T_66479_row8_col11, #T_66479_row9_col9, #T_66479_row9_col10, #T_66479_row9_col11, #T_66479_row10_col10, #T_66479_row10_col11, #T_66479_row11_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_66479_row1_col0, #T_66479_row7_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_66479_row2_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_66479_row2_col1 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_66479_row3_col0 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_66479_row3_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_66479_row3_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_66479_row4_col0, #T_66479_row6_col4, #T_66479_row8_col0 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_66479_row4_col1, #T_66479_row4_col2 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_66479_row4_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_66479_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_66479_row5_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_66479_row5_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_66479_row5_col3, #T_66479_row8_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_66479_row5_col4, #T_66479_row6_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_66479_row6_col0 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_66479_row6_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_66479_row6_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_66479_row6_col3, #T_66479_row7_col0, #T_66479_row9_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_66479_row7_col1 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_66479_row7_col3 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_66479_row7_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_66479_row7_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_66479_row7_col6 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_66479_row8_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_66479_row8_col2 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_66479_row8_col3 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_66479_row8_col4 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_66479_row8_col6, #T_66479_row11_col7 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_66479_row8_col7 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_66479_row9_col0 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_66479_row9_col1 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_66479_row9_col2 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_66479_row9_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_66479_row9_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_66479_row9_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_66479_row9_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_66479_row9_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_66479_row10_col0, #T_66479_row11_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_66479_row10_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_66479_row10_col2, #T_66479_row10_col5 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_66479_row10_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_66479_row10_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_66479_row10_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_66479_row10_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_66479_row10_col8 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_66479_row10_col9 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_66479_row11_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_66479_row11_col2, #T_66479_row11_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_66479_row11_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_66479_row11_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_66479_row11_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_66479_row11_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_66479_row11_col8 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_66479_row11_col9 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66479_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CO(GT)</th>
#       <th class="col_heading level0 col1" >PT08.S1(CO)</th>
#       <th class="col_heading level0 col2" >C6H6(GT)</th>
#       <th class="col_heading level0 col3" >PT08.S2(NMHC)</th>
#       <th class="col_heading level0 col4" >NOx(GT)</th>
#       <th class="col_heading level0 col5" >PT08.S3(NOx)</th>
#       <th class="col_heading level0 col6" >NO2(GT)</th>
#       <th class="col_heading level0 col7" >PT08.S4(NO2)</th>
#       <th class="col_heading level0 col8" >PT08.S5(O3)</th>
#       <th class="col_heading level0 col9" >T</th>
#       <th class="col_heading level0 col10" >RH</th>
#       <th class="col_heading level0 col11" >AH</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66479_level0_row0" class="row_heading level0 row0" >CO(GT)</th>
#       <td id="T_66479_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_66479_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_66479_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_66479_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_66479_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_66479_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_66479_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_66479_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_66479_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_66479_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_66479_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_66479_row0_col11" class="data row0 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_66479_level0_row1" class="row_heading level0 row1" >PT08.S1(CO)</th>
#       <td id="T_66479_row1_col0" class="data row1 col0" >0.77</td>
#       <td id="T_66479_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_66479_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_66479_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_66479_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_66479_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_66479_row1_col6" class="data row1 col6" >n

# %% [markdown]
# ## NORMALIZATION
# Using min-max normalization:

# %%
#Normalising data
from sklearn.preprocessing import MinMaxScaler

df = dataset.drop(columns = ['Date', 'Time'])
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(df.values)

'''df = dataset.drop(columns = ['Date', 'Time'])
df = (df-df.min())/(df.max()-df.min())'''
df = pd.DataFrame(df_scaled, columns = df.columns)
df
# Out:
#         CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)   NOx(GT)  PT08.S3(NOx)  \
# 0     0.211864     0.511849  0.184498       0.361737  0.111036      0.311024
# 1     0.161017     0.463196  0.145428       0.312167  0.068382      0.360796
# 2     0.177966     0.542011  0.139148       0.303701  0.087339      0.346500
# 3     0.177966     0.522980  0.142780       0.308617  0.115098      0.326168
# 4     0.127119     0.448833  0.100156       0.247030  0.087339      0.374034
# ...        ...          ...       ...            ...       ...           ...
# 9352  0.254237     0.478995  0.210411       0.392189  0.318009      0.091708
# 9353  0.194915     0.370018  0.176218       0.351632  0.237847      0.119348
# 9354  0.194915     0.355296  0.192248       0.371023  0.197021      0.119136
# 9355  0.169492     0.255117  0.147787       0.315308  0.157414      0.160754
# 9356  0.177966     0.304129  0.185290       0.362693  0.178199      0.140633
#
#        NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)         T        RH        AH
# 0     0.328694      0.513040     0.454654  0.333333  0.499057  0.280046
# 1     0.266509      0.453125     0.326382  0.326882  0.484287  0.264279
# 2     0.331655      0.451214     0.370588  0.296774  0.563168  0.276374
# 3     0.355345      0.464366     0.426741  0.277419  0.638906  0.294198
# 4     0.337578      0.422212     0.386228  0.280645  0.633564  0.295215
# ...        ...           ...          ...       ...       ...       ...
# 9352  0.556115      0.370166     0.654936  0.510753  0.252357  0.279592
# 9353  0.524726      0.320369     0.455306  0.563978  0.182904  0.257621
# 9354  0.511401      0.310139     0.378408  0.619355  0.115336  0.222820
# 9355  0.455138      0.220324     0.238406  0.650000  0.054997  0.160865
# 9356  0.490672      0.259667     0.258499  0.653763  0.049654  0.155459
#
# [9357 rows x 12 columns]

# %%
df.describe(include = 'all').T
# Out:
#                 count      mean       std  min       25%       50%       75%  \
# CO(GT)         9357.0  0.173962  0.111531  0.0  0.093220  0.173962  0.211864
# PT08.S1(CO)    9357.0  0.324925  0.152816  0.0  0.211131  0.306822  0.412208
# C6H6(GT)       9357.0  0.156213  0.114832  0.0  0.069858  0.132788  0.212086
# PT08.S2(NMHC)  9357.0  0.303580  0.142869  0.0  0.196231  0.294961  0.394101
# NOx(GT)        9357.0  0.165796  0.130954  0.0  0.074475  0.153690  0.191063
# PT08.S3(NOx)   9357.0  0.217461  0.106636  0.0  0.145505  0.209891  0.270359
# NO2(GT)        9357.0  0.328918  0.130030  0.0  0.248445  0.328918  0.387918
# PT08.S4(NO2)   9357.0  0.406989  0.152592  0.0  0.310477  0.406989  0.499550
# PT08.S5(O3)    9357.0  0.348335  0.169701  0.0  0.226241  0.330835  0.449332
# T              9357.0  0.434754  0.186202  0.0  0.299462  0.433871  0.558602
# RH             9357.0  0.503549  0.213379  0.0  0.344123  0.503549  0.662476
# AH             9357.0  0.410902  0.193434  0.0  0.274359  0.405971  0.543182
#
#                max
# CO(GT)         1.0
# PT08.S1(CO)    1.0
# C6H6(GT)       1.0
# PT08.S2(NMHC)  1.0
# NOx(GT)        1.0
# PT08.S3(NOx)   1.0
# NO2(GT)        1.0
# PT08.S4(NO2)   1.0
# PT08.S5(O3)    1.0
# T              1.0
# RH             1.0
# AH             1.0

# %%
df.boxplot(figsize= (18,10))

# %% [markdown]
# ## **CO forecasting with LSTM**
# Let's specify what we want to do: **for each hour we want to predict the CO concentration based on the CO concentration values of the two previous days by using LSTM and Bidirectional-LSTM.** Since there are some constraints concerning the input shape of these models, we're going to do this:
# - we split the dataset in **two tensors X and Y** with shape respectively **(n_obs-lookback, lookback, n_features)** and **(n_obs-lookback, 1)**. The first tensor contains for each hour (so for each timestep) the array containing the lookback previous observation (each observation has 12 features, included the CO concentration). The second tensor contains for each timestep the corresponding CO concentration value. In this way we can make the model supervised.
# - we split X and Y in in two sets: one for the **training (85%)** and the other for the **testing (15%)**

# %%
lookback = 24*2
step = 1
delay = 24
batch_size = 1
train_size = int(len(df)*0.85)
test_size = len(df) - train_size
print(train_size, test_size)
# Out:
# 7953 1404

# %%
#Creating a window for previous data
def to_supervised(train, lookback):
  X = []
  Y = []
  for i in range(lookback, len(train)):
    X.append(train.iloc[i-lookback:i,:])
    Y.append(train.iloc[i,0:1])
    
  return X,Y

# %%
X, Y = to_supervised(train = df, lookback = lookback)
X = np.array(X)
Y = np.array(Y)
print('Y' ,Y.shape)
print('X' ,X.shape)
# Out:
# Y (9309, 1)
# X (9309, 48, 12)

# %%
#Splitting the dataset
X_train, X_test = X[:train_size,] , X[train_size:,]
print('X_train' ,X_train.shape)
print('X_test' ,X_test.shape)

Y_train, Y_test = Y[:train_size,0:1] , Y[train_size:,0:1]
print('Y_train' ,Y_train.shape)
print('Y_test' ,Y_test.shape)

# per ogni elemento che voglio prevedere (Y) ho a disposizion come un mini dataset 
# fatto dalle 48 osservazioni precedenti, quindi di size 48*12 (ho 12 colonne)
# Out:
# X_train (7953, 48, 12)
# X_test (1356, 48, 12)
# Y_train (7953, 1)
# Y_test (1356, 1)

# %%
#Importing LSTM model
from keras.models import Sequential
from keras.layers import Dense, Dropout,LSTM
model_lstm_1 = Sequential()

model_lstm_1.add(LSTM(units = 32, return_sequences = False, input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm_1.add(Dense(units = 1))

model_lstm_1.compile(optimizer = 'adam', loss = 'mean_squared_error')
#Train the model
lstm_1 = model_lstm_1.fit(X_train, Y_train, epochs = 50, batch_size = 30, validation_split = 0.2)
lstm_1
model_lstm_1.save('air_pollution_lstm_1.h5')
# Out:
# Epoch 1/50
# 213/213 [==============================] - 8s 9ms/step - loss: 0.0091 - val_loss: 0.0075
# Epoch 2/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 3/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 4/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0046
# Epoch 5/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 6/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 7/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 8/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 9/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 10/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0043
# Epoch 11/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 12/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0031 - val_loss: 0.0042
# Epoch 13/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0030 - val_loss: 0.0044
# Epoch 14/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0029 - val_loss: 0.0042
# Epoch 15/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 16/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0028 - val_loss: 0.0047
# Epoch 17/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 18/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 19/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 20/50
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 21/50
# 213/213 [==============================] - 2s 7ms/step - loss: 0.0026 - val_loss: 0.0041
# Epoch 22/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 23/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 24/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 25/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 26/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 27/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0026 - val_loss: 0.0039
# Epoch 28/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 29/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 30/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0041
# Epoch 31/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0025 - val_loss: 0.0039
# Epoch 32/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 33/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 34/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 35/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 36/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 37/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 38/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 39/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0024 - val_loss: 0.0040
# Epoch 40/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 41/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 42/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 43/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 44/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 45/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0038
# Epoch 46/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 47/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 48/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 49/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 50/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0023 - val_loss: 0.0039

# %%
loss = lstm_1.history['loss']
val_loss = lstm_1.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model_lstm_dropout_1 = Sequential()

model_lstm_dropout_1.add(LSTM(units = 32, return_sequences = False, input_shape=(X_train.shape[1], X_train.shape[2])))
model_lstm_dropout_1.add(Dropout(0.2))
model_lstm_dropout_1.add(Dense(units = 1))

model_lstm_dropout_1.compile(optimizer = 'adam', loss = 'mean_squared_error')

#Train the model
lstm_dropout_1 = model_lstm_dropout_1.fit(X_train, Y_train, epochs = 50, batch_size = 30, validation_split = 0.2)
lstm_dropout_1
model_lstm_dropout_1.save('air_pollution_lstm_dropout_1.h5')
# Out:
# Epoch 1/50
# 213/213 [==============================] - 3s 8ms/step - loss: 0.0103 - val_loss: 0.0075
# Epoch 2/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 3/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 4/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 5/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 6/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 7/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 8/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0036 - val_loss: 0.0043
# Epoch 9/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0037 - val_loss: 0.0043
# Epoch 10/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 11/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0045
# Epoch 12/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 13/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0047
# Epoch 14/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 15/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0040
# Epoch 16/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 17/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0040
# Epoch 18/50
# 213/213 [==============================] - 1s 5ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 19/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 20/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0040
# Epoch 21/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0038
# Epoch 22/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0031 - val_loss: 0.0037
# Epoch 23/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0030 - val_loss: 0.0039
# Epoch 24/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0043
# Epoch 25/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0040
# Epoch 26/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0039
# Epoch 27/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 28/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 29/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 30/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 31/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 32/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0029 - val_loss: 0.0037
# Epoch 33/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0028 - val_loss: 0.0037
# Epoch 34/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 35/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0038
# Epoch 36/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 37/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 38/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 39/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 40/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0041
# Epoch 41/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 42/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 43/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 44/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 45/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 46/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0037
# Epoch 47/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0026 - val_loss: 0.0037
# Epoch 48/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0038
# Epoch 49/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 50/50
# 213/213 [==============================] - 1s 6ms/step - loss: 0.0026 - val_loss: 0.0038

# %%
loss = lstm_dropout_1.history['loss']
val_loss = lstm_dropout_1.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
Y_pred = model_lstm_1.predict(X_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test, Y_pred)

rmse = np.sqrt(mse)
rmse
# Out:
# 43/43 [==============================] - 0s 3ms/step
# 0.05467070727675954

# %%
print(Y_pred.shape, Y_test.shape, df.shape)
# Out:
# (1356, 1) (1356, 1) (9357, 12)

# %% [markdown]
# If we want to see the forecasting plot and compare the predicted values with the actual ones we have to do the inverse scaling.

# %%
#Scaling back to the original scale
df_test_truncated = df.iloc[train_size+lookback:,1:]
#print(df_truncated.shape)
#print('Y_pred',Y_pred.shape)
df_test_with_Y_predicted = np.concatenate((df_test_truncated.iloc[:,:],Y_pred), axis =1)
df_test_with_Y_predicted = pd.DataFrame(df_test_with_Y_predicted)
print(df_test_with_Y_predicted)
print('concat y_pred',Y_pred.shape)
df_test_with_Y_tested = np.concatenate((df_test_truncated.iloc[:,:], Y_test), axis = 1)
df_test_with_Y_tested = pd.DataFrame(df_test_with_Y_tested)
print('concat Y_test', Y_test.shape)
print(df_test_with_Y_predicted.shape)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.153321  0.016530  0.073740  0.165796  0.346818  0.328918  0.083858
# 1     0.147217  0.010729  0.053667  0.043737  0.366197  0.186852  0.078575
# 2     0.166607  0.012793  0.061177  0.049492  0.349253  0.208765  0.090715
# 3     0.181149  0.017605  0.077154  0.064252  0.325320  0.244596  0.103080
# 4     0.226750  0.035811  0.126314  0.118280  0.278725  0.388807  0.128597
# ...        ...       ...       ...       ...       ...       ...       ...
# 1351  0.478995  0.210411  0.392189  0.318009  0.091708  0.556115  0.370166
# 1352  0.370018  0.176218  0.351632  0.237847  0.119348  0.524726  0.320369
# 1353  0.355296  0.192248  0.371023  0.197021  0.119136  0.511401  0.310139
# 1354  0.255117  0.147787  0.315308  0.157414  0.160754  0.455138  0.220324
# 1355  0.304129  0.185290  0.362693  0.178199  0.140633  0.490672  0.259667
#
#             7         8         9         10        11
# 0     0.113175  0.124194  0.385921  0.068586  0.081024
# 1     0.119474  0.122581  0.400377  0.072330  0.095679
# 2     0.174541  0.111828  0.445946  0.080730  0.052120
# 3     0.206256  0.119355  0.444375  0.084397  0.064561
# 4     0.301836  0.114516  0.475173  0.091184  0.076119
# ...        ...       ...       ...       ...       ...
# 1351  0.654936  0.510753  0.252357  0.279592  0.229424
# 1352  0.455306  0.563978  0.182904  0.257621  0.232195
# 1353  0.378408  0.619355  0.115336  0.222820  0.209560
# 1354  0.238406  0.650000  0.054997  0.160865  0.210773
# 1355  0.258499  0.653763  0.049654  0.155459  0.189332
#
# [1356 rows x 12 columns]
# concat y_pred (1356, 1)
# concat Y_test (1356, 1)
# (1356, 12)

# %% [markdown]
# I have to reorder the columns otherwise we can't apply the inverse-scaling with scikitlearn.

# %%
cols = df_test_with_Y_predicted.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_test_with_Y_predicted = df_test_with_Y_predicted[cols]
df_test_with_Y_tested = df_test_with_Y_tested[cols]

# %%
print(df_test_with_Y_tested)
# Out:
#             11        0         1         2         3         4         5   \
# 0     0.042373  0.153321  0.016530  0.073740  0.165796  0.346818  0.328918
# 1     0.042373  0.147217  0.010729  0.053667  0.043737  0.366197  0.186852
# 2     0.042373  0.166607  0.012793  0.061177  0.049492  0.349253  0.208765
# 3     0.042373  0.181149  0.017605  0.077154  0.064252  0.325320  0.244596
# 4     0.059322  0.226750  0.035811  0.126314  0.118280  0.278725  0.388807
# ...        ...       ...       ...       ...       ...       ...       ...
# 1351  0.254237  0.478995  0.210411  0.392189  0.318009  0.091708  0.556115
# 1352  0.194915  0.370018  0.176218  0.351632  0.237847  0.119348  0.524726
# 1353  0.194915  0.355296  0.192248  0.371023  0.197021  0.119136  0.511401
# 1354  0.169492  0.255117  0.147787  0.315308  0.157414  0.160754  0.455138
# 1355  0.177966  0.304129  0.185290  0.362693  0.178199  0.140633  0.490672
#
#             6         7         8         9         10
# 0     0.083858  0.113175  0.124194  0.385921  0.068586
# 1     0.078575  0.119474  0.122581  0.400377  0.072330
# 2     0.090715  0.174541  0.111828  0.445946  0.080730
# 3     0.103080  0.206256  0.119355  0.444375  0.084397
# 4     0.128597  0.301836  0.114516  0.475173  0.091184
# ...        ...       ...       ...       ...       ...
# 1351  0.370166  0.654936  0.510753  0.252357  0.279592
# 1352  0.320369  0.455306  0.563978  0.182904  0.257621
# 1353  0.310139  0.378408  0.619355  0.115336  0.222820
# 1354  0.220324  0.238406  0.650000  0.054997  0.160865
# 1355  0.259667  0.258499  0.653763  0.049654  0.155459
#
# [1356 rows x 12 columns]

# %%
Y_predicted = scaler.inverse_transform(df_test_with_Y_predicted)
Y_tested = scaler.inverse_transform(df_test_with_Y_tested)
Y_predicted = Y_predicted[:,0:1]
Y_tested = Y_tested[:,0:1]
print('Y_tested', Y_tested.shape)
print('Y_predicted', Y_predicted.shape)
# Out:
# Y_tested (1356, 1)
# Y_predicted (1356, 1)

# %%
mse = mean_squared_error(Y_tested, Y_predicted)

rmse = np.sqrt(mse)
rmse
# Out:
# 0.6451143458657626

# %%
#Plot the graph between actual vs predicted values
plt.figure(figsize=(18,6))  
plt.plot(Y_predicted[-100:,:], color= 'green',label = 'Predicted CO (GT)')
plt.plot(Y_tested[-100:,:] , color = 'red',label = 'Actual CO (GT)')
plt.title("Air Pollution from CO (GT) Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("CO (GT)")
plt.legend()
plt.show()
plt.savefig('graph.png')

# %% [markdown]
# # BIDIRECTIONAL LSTM

# %%
import numpy as np
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional
from keras.datasets import imdb

# %%
model = Sequential()
model.add(Bidirectional(LSTM(32)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
history=model.fit(X_train, Y_train,
          batch_size=30,
          epochs=50,
          validation_split=0.2)
print(history.history['loss'])
print(history.history['accuracy'])
# Out:
# Epoch 1/50
# 213/213 [==============================] - 6s 12ms/step - loss: 0.0146 - accuracy: 0.0027 - val_loss: 0.0131 - val_accuracy: 0.0050
# Epoch 2/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0073 - accuracy: 0.0027 - val_loss: 0.0093 - val_accuracy: 0.0050
# Epoch 3/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0059 - accuracy: 0.0028 - val_loss: 0.0075 - val_accuracy: 0.0050
# Epoch 4/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0051 - accuracy: 0.0027 - val_loss: 0.0071 - val_accuracy: 0.0050
# Epoch 5/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0046 - accuracy: 0.0028 - val_loss: 0.0058 - val_accuracy: 0.0050
# Epoch 6/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0042 - accuracy: 0.0028 - val_loss: 0.0053 - val_accuracy: 0.0050
# Epoch 7/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0040 - accuracy: 0.0028 - val_loss: 0.0052 - val_accuracy: 0.0050
# Epoch 8/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0039 - accuracy: 0.0028 - val_loss: 0.0051 - val_accuracy: 0.0050
# Epoch 9/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0038 - accuracy: 0.0028 - val_loss: 0.0048 - val_accuracy: 0.0050
# Epoch 10/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0037 - accuracy: 0.0028 - val_loss: 0.0048 - val_accuracy: 0.0050
# Epoch 11/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0037 - accuracy: 0.0028 - val_loss: 0.0046 - val_accuracy: 0.0050
# Epoch 12/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0035 - accuracy: 0.0028 - val_loss: 0.0046 - val_accuracy: 0.0050
# Epoch 13/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0036 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 14/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0034 - accuracy: 0.0028 - val_loss: 0.0045 - val_accuracy: 0.0050
# Epoch 15/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0034 - accuracy: 0.0028 - val_loss: 0.0045 - val_accuracy: 0.0050
# Epoch 16/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0033 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 17/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0032 - accuracy: 0.0028 - val_loss: 0.0045 - val_accuracy: 0.0050
# Epoch 18/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0033 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 19/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0032 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 20/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 21/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0033 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 22/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 23/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 24/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.0028 - val_loss: 0.0044 - val_accuracy: 0.0050
# Epoch 25/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0031 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 26/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 27/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 28/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 29/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0029 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 30/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 31/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 32/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0030 - accuracy: 0.0028 - val_loss: 0.0040 - val_accuracy: 0.0050
# Epoch 33/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 34/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 35/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 36/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0029 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 37/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0039 - val_accuracy: 0.0050
# Epoch 38/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0042 - val_accuracy: 0.0050
# Epoch 39/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0045 - val_accuracy: 0.0050
# Epoch 40/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0039 - val_accuracy: 0.0050
# Epoch 41/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0028 - accuracy: 0.0028 - val_loss: 0.0043 - val_accuracy: 0.0050
# Epoch 42/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0027 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 43/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0027 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 44/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0027 - accuracy: 0.0028 - val_loss: 0.0043 - val_accuracy: 0.0050
# Epoch 45/50
# 213/213 [==============================] - 2s 8ms/step - loss: 0.0026 - accuracy: 0.0028 - val_loss: 0.0039 - val_accuracy: 0.0050
# Epoch 46/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0026 - accuracy: 0.0028 - val_loss: 0.0040 - val_accuracy: 0.0050
# Epoch 47/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0026 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 48/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0026 - accuracy: 0.0028 - val_loss: 0.0047 - val_accuracy: 0.0050
# Epoch 49/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0025 - accuracy: 0.0028 - val_loss: 0.0041 - val_accuracy: 0.0050
# Epoch 50/50
# 213/213 [==============================] - 2s 9ms/step - loss: 0.0025 - accuracy: 0.0028 - val_loss: 0.0039 - val_accuracy: 0.0050
# [0.014607557095587254, 0.007337009999901056, 0.0058964830823242664, 0.0050938609056174755, 0.00457274354994297, 0.004238459747284651, 0.004006057046353817, 0.003863313002511859, 0.00378871220164001, 0.0036725483369082212, 0.00366408983245492, 0.003517086384817958, 0.0035667172633111477, 0.003417733358219266, 0.0034238307271152735, 0.0032823062501847744, 0.0032374877482652664, 0.0032910259906202555, 0.003240650985389948, 0.0031260335817933083, 0.0032775825820863247, 0.0031489457469433546, 0.0031427911017090082, 0.0031184563413262367, 0.0030831126496195793, 0.0030318829230964184, 0.0030190078541636467, 0.0030230162665247917, 0.0029451358132064342, 0.0029634488746523857, 0.002974859206005931, 0.0029623580630868673, 0.0028404654003679752, 0.0028285367880016565, 0.0028329112101346254, 0.002864027163013816, 0.0027879346162080765, 0.0027735435869544744, 0.0027630592230707407, 0.002774077234789729, 0.0027780106756836176, 0.0027261392679065466, 0.002693766262382269, 0.002654807176440954, 0.0026061972603201866, 0.0026324763894081116, 0.0025849274825304747, 0.0025966574903577566, 0.002518443390727043, 0.002545045455917716]
# [0.0026721155736595392, 0.0026721155736595392, 0.0028292990755289793, 0.0026721155736595392, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793, 0.0028292990755289793]

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['accuracy'])
pyplot.title('model loss vs accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['loss', 'accuracy'], loc='upper right')
pyplot.show()

# %%
Y_pred_b = model.predict(X_test)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test, Y_pred_b)

rmse = np.sqrt(mse)
rmse
# Out:
# 43/43 [==============================] - 1s 4ms/step
# 0.0535319516248256

# %%
#Scaling back to the original scale
df_test_truncated = df.iloc[train_size+lookback:,1:]
#print(df_truncated.shape)
#print('Y_pred_b',Y_pred_b.shape)
df_test_with_Y_predicted_b = np.concatenate((df_test_truncated.iloc[:,:],Y_pred_b), axis =1)
df_test_with_Y_predicted_b = pd.DataFrame(df_test_with_Y_predicted_b)
print(df_test_with_Y_predicted_b)
print('concat y_pred',Y_pred_b.shape)

# PER df_test non è cambiato nulla (Y_test è sempre la stessa)
# df_test_with_Y_tested = np.concatenate((df_test_truncated.iloc[:,:], Y_test), axis = 1)
# df_test_with_Y_tested = pd.DataFrame(df_test_with_Y_tested)
# print('concat Y_test', Y_test.shape)
# print(df_test_with_Y_predicted.shape)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.153321  0.016530  0.073740  0.165796  0.346818  0.328918  0.083858
# 1     0.147217  0.010729  0.053667  0.043737  0.366197  0.186852  0.078575
# 2     0.166607  0.012793  0.061177  0.049492  0.349253  0.208765  0.090715
# 3     0.181149  0.017605  0.077154  0.064252  0.325320  0.244596  0.103080
# 4     0.226750  0.035811  0.126314  0.118280  0.278725  0.388807  0.128597
# ...        ...       ...       ...       ...       ...       ...       ...
# 1351  0.478995  0.210411  0.392189  0.318009  0.091708  0.556115  0.370166
# 1352  0.370018  0.176218  0.351632  0.237847  0.119348  0.524726  0.320369
# 1353  0.355296  0.192248  0.371023  0.197021  0.119136  0.511401  0.310139
# 1354  0.255117  0.147787  0.315308  0.157414  0.160754  0.455138  0.220324
# 1355  0.304129  0.185290  0.362693  0.178199  0.140633  0.490672  0.259667
#
#             7         8         9         10        11
# 0     0.113175  0.124194  0.385921  0.068586  0.045128
# 1     0.119474  0.122581  0.400377  0.072330  0.071062
# 2     0.174541  0.111828  0.445946  0.080730  0.034245
# 3     0.206256  0.119355  0.444375  0.084397  0.041023
# 4     0.301836  0.114516  0.475173  0.091184  0.083767
# ...        ...       ...       ...       ...       ...
# 1351  0.654936  0.510753  0.252357  0.279592  0.260397
# 1352  0.455306  0.563978  0.182904  0.257621  0.241087
# 1353  0.378408  0.619355  0.115336  0.222820  0.211692
# 1354  0.238406  0.650000  0.054997  0.160865  0.206355
# 1355  0.258499  0.653763  0.049654  0.155459  0.167000
#
# [1356 rows x 12 columns]
# concat y_pred (1356, 1)

# %%
# Devo riordinare le colonne perchè altrimenti non posso applicare l'inverso dello scaling fatto all'inizio 

cols = df_test_with_Y_predicted_b.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_test_with_Y_predicted_b = df_test_with_Y_predicted_b[cols]

# df_test_with_Y_tested = df_test_with_Y_tested[cols]

# %%
Y_predicted_b = scaler.inverse_transform(df_test_with_Y_predicted_b)
# Y_tested = scaler.inverse_transform(df_test_with_Y_tested)
Y_predicted_b = Y_predicted_b[:,0:1]
# Y_tested = Y_tested[:,0:1]
print('Y_tested', Y_tested.shape)
print('Y_predicted_b', Y_predicted_b.shape)
# Out:
# Y_tested (1356, 1)
# Y_predicted_b (1356, 1)

# %%
mse = mean_squared_error(Y_tested, Y_predicted_b)

rmse = np.sqrt(mse)
rmse
# Out:
# 0.6316770291729421

# %%
#Plot the graph between actual vs predicted values
plt.figure(figsize=(18,6))  
plt.plot(Y_pred_b[-100:,:], color= 'green',label = 'Predicted CO (GT)')
plt.plot(Y_test[-100:,:] , color = 'red',label = 'Actual CO (GT)')
plt.title("Air Pollution from CO (GT) Prediction (Multivariate)")
plt.xlabel("Date")
plt.ylabel("CO (GT)")
plt.legend()
plt.show()
plt.savefig('graph.png')
